# %%
from datasets import load_dataset

ds = load_dataset("snae/emotion_stories_gemma_4_4B", split="train")
ds
# Out:
# Dataset({
#     features: ['emotion', 'topic', 'prompt', 'raw_response', 'stories', 'n_stories_parsed', 'timestamp'],
#     num_rows: 513
# })

# %%
train_data = ds.to_pandas()

# %%
train_data.head()
# Out:
#     emotion                                              topic  \
# 0  brooding  A person discovers their mentor has retired wi...
# 1  brooding  A person finds out their biography was written...
# 2  brooding  Someone discovers their partner has been writi...
# 3    gloomy  A homeowner discovers previous residents left ...
# 4    gloomy  A person finds out their partner has been lear...
#
#                                               prompt  \
# 0  Write 3 different stories based on the followi...
# 1  Write 3 different stories based on the followi...
# 2  Write 3 different stories based on the followi...
# 3  Write 3 different stories based on the followi...
# 4  Write 3 different stories based on the followi...
#
#                                         raw_response  \
# 0  [story 1]\nThe silence in the studio was a phy...
# 1  [story 1]\nElias traced the rim of his lukewar...
# 2  [story 1]\nThe rain lashed against the attic w...
# 3  [story 1]\nElias dragged the heavy wooden ladd...
# 4  [story 1]\nRain lashed against the apartment w...
#
#                                              stories  n_stories_parsed  \
# 0  [The silence in the studio was a physical weig...                 3
# 1  [Elias traced the rim of his lukewarm coffee m...                 3
# 2  [The rain lashed against the attic window, mir...                 3
# 3  [Elias dragged the heavy wooden ladder across ...                 3
# 4  [Rain lashed against the apartment window, eac...                 3
#
#                     timestamp
# 0  2026-04-21T14:14:39.210458
# 1  2026-04-21T14:15:24.483513
# 2  2026-04-21T14:15:56.575464
# 3  2026-04-21T14:16:23.974985
# 4  2026-04-21T14:17:04.038691

# %%
train_data.emotion.describe()
# Out:
# count          513
# unique         171
# top       brooding
# freq             3
# Name: emotion, dtype: object
